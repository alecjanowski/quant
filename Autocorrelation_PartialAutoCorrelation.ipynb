# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
# %matplotlib inline
import dask.dataframe as dd
from tqdm import tqdm 
import warnings
warnings.filterwarnings(action = 'once')

# %%
# Importing the dataset
fileNames = ["metaData", "Symbol0 2"]
frames = []
for index, fileName in tqdm(enumerate(fileNames)):
    frames.append(dd.read_csv(fileName + ".csv", sep=",", sample = 2000000))
# Out:
# 2it [00:00, 16.61it/s]

# %%
dta = pd.read_csv("Symbol0 2.csv")
sm.graphics.tsa.plot_acf(dta.iloc[:, 1].values.squeeze(), lags=100)
plt.show()

# %%
sm.graphics.tsa.plot_pacf(dta.values.squeeze(), lags=50)
plt.show()
